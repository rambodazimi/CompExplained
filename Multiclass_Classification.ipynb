# %%
# CompExplained YouTube Channel
# Author: Rambod Azimi

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

X, y = make_blobs(n_samples=300, centers=3, cluster_std=5.0, n_features=2, random_state=42)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy = {accuracy}")

print(classification_report(y_test, y_pred))

plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.get_cmap('viridis', 3))
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Generated Data')
plt.colorbar(label='Class')
plt.show()
# Out:
# Accuracy = 0.8833333333333333
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93        22
#            1       0.84      0.89      0.86        18
#            2       0.85      0.85      0.85        20
#
#     accuracy                           0.88        60
#    macro avg       0.88      0.88      0.88        60
# weighted avg       0.89      0.88      0.88        60
# <ipython-input-21-9a8bd7aa8954>:27: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.get_cmap('viridis', 3))
